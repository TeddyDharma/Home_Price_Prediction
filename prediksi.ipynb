# %%
import tensorflow as tf
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("harga_rumah.csv")
data
# Out:
#        jml_lantai  ruangan  luas (m2)     harga
# 0               2        2      40.50  235000.0
# 1               1        3      53.00  760000.0
# 2              10        1      28.00  320000.0
# 3               1        3      64.00  375000.0
# 4               9        2      47.80  450000.0
# ...           ...      ...        ...       ...
# 23759           0        2      48.00  358100.0
# 23760           0        3      67.53  499000.0
# 23761           0        3      58.04  510752.0
# 23762           1        1      31.29  499497.0
# 23763           8        3      56.00  520000.0
#
# [23764 rows x 4 columns]

# %%
jumlah_lantai = data['jml_lantai']
jumlah_ruangan = data['ruangan']
luas = data['luas (m2)']
harga = data['harga']

# %%
all_data = [[lantai, ruangan, area] for lantai, ruangan, area in zip(jumlah_lantai, jumlah_ruangan, luas)]
for x in range(5): 
    print(all_data[x])
all_data = np.array(all_data)
harga = np.array(harga)
# Out:
# [2, 2, 40.5]
# [1, 3, 53.0]
# [10, 1, 28.0]
# [1, 3, 64.0]
# [9, 2, 47.8]

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=[3])
])

# %%
model.compile( 
    loss='mae', 
    optimizer='sgd',
    metrics=['accuracy']
)

# %%
model.fit(all_data, harga, epochs=500)
# Out:
# Epoch 1/500
# 743/743 [==============================] - 0s 566us/step - loss: 538571.2500 - accuracy: 0.0000e+00
# Epoch 2/500
# 743/743 [==============================] - 0s 564us/step - loss: 538605.0000 - accuracy: 0.0000e+00
# Epoch 3/500
# 743/743 [==============================] - 0s 551us/step - loss: 538536.1250 - accuracy: 0.0000e+00
# Epoch 4/500
# 743/743 [==============================] - 0s 557us/step - loss: 538507.5000 - accuracy: 0.0000e+00
# Epoch 5/500
# 743/743 [==============================] - 0s 551us/step - loss: 538302.6875 - accuracy: 0.0000e+00
# Epoch 6/500
# 743/743 [==============================] - 0s 553us/step - loss: 538353.9375 - accuracy: 0.0000e+00
# Epoch 7/500
# 743/743 [==============================] - 0s 568us/step - loss: 538288.3750 - accuracy: 0.0000e+00
# Epoch 8/500
# 743/743 [==============================] - 0s 539us/step - loss: 538224.4375 - accuracy: 0.0000e+00
# Epoch 9/500
# ...
